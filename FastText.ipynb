# %% [markdown]
# ##**FastText**

# %%
# !pip install fasttext
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 3.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached pybind11-3.0.4-py3-none-any.whl.metadata (10 kB)
# ...
# Using cached pybind11-3.0.4-py3-none-any.whl (314 kB)
# ...
#   Created wheel for fasttext: filename=fasttext-0.9.3-cp312-cp312-linux_x86_64.whl size=4653910 sha256=d051ea9fc64fc58436684c3d84cfb7e18109f5d177acf9b4a907dba73229d95d
#   Stored in directory: /root/.cache/pip/wheels/20/27/95/a7baf1b435f1cbde017cabdf1e9688526d2b0e929255a359c6
# Successfully built fasttext
# ...

# %%
import fasttext
